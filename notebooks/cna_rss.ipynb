# %% [markdown]
# ## CNA RSS feeds
#
# Libraries:
# - feedparser
# - unidecode
#
# RSS Links:
# - Latest News: https://www.channelnewsasia.com/api/v1/rss-outbound-feed?_format=xml
#
# - Asia: https://www.channelnewsasia.com/api/v1/rss-outbound-feed?_format=xml&category=6511
#
# - Business: https://www.channelnewsasia.com/api/v1/rss-outbound-feed?_format=xml&category=6936
#
# - Singapore: https://www.channelnewsasia.com/api/v1/rss-outbound-feed?_format=xml&category=10416
#
# - Sport: https://www.channelnewsasia.com/api/v1/rss-outbound-feed?_format=xml&category=10296
#
# - World: https://www.channelnewsasia.com/api/v1/rss-outbound-feed?_format=xml&category=6311

# %%
import feedparser

url = "https://www.channelnewsasia.com/api/v1/rss-outbound-feed?_format=xml&category=6936"
feed = feedparser.parse(url)
print(len(feed["entries"]))
feed
# Out:
# 20
# {'bozo': False,
#  'entries': [{'title': 'Hong Kong home prices rise 0.3% in April from March',
#    'title_detail': {'type': 'text/plain',
#     'language': 'en',
#     'base': 'https://www.channelnewsasia.com/',
#     'value': 'Hong Kong home prices rise 0.3% in April from March'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.channelnewsasia.com/business/hong-kong-home-prices-rise-03-april-march-4370871'}],
#    'link': 'https://www.channelnewsasia.com/business/hong-kong-home-prices-rise-03-april-march-4370871',
#    'summary': '',
#    'summary_detail': {'type': 'text/html',
#     'language': 'en',
#     'base': 'https://www.channelnewsasia.com/',
#     'value': ''},
#    'published': 'Wed, 29 May 2024 14:15:03 +0800',
#    'published_parsed': time.struct_time(tm_year=2024, tm_mon=5, tm_mday=29, tm_hour=6, tm_min=15, tm_sec=3, tm_wday=2, tm_yday=150, tm_isdst=0),
#    'id': 'https://www.channelnewsasia.com/business/hong-kong-home-prices-rise-03-april-march-4370871',
#    'guidislink': False,
#    'tags': [{'term': 'Business', 'scheme': None, 'label': None}],
#    'media_thumbnail': [{'url': 'https://onecms-res.cloudinary.com/image/upload/s--rufL9XqJ--/c_fill,h_900,w_1600/fl_relative,g_south_east,l_mediacorp:cna:watermark:2024-04:reuters_1,w_0.1/f_auto,q_auto/v1/one-cms/core/2024-05-29t061503z_1_lynxmpek4s078_rtroptp_3_hongkong-extradition-youngpeople.jpg?itok=BFY0Y11R',
#      'width': '1600',
#      'height': '900'}],
#    'href': ''},
#   {'title': 'Seeking OECD membership, Indonesia reviews economic policies',
#    'title_detail': {'type': 'text/plain',
#     'language': 'en',
#     'base': 'https://www.channelnewsasia.com/',
#     'value': 'Seeking OECD membership, Indonesia reviews economic policies'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.channelnewsasia.com/business/seeking-oecd-membership-indonesia-reviews-economic-policies-4370811'}],
#    'link': 'https://www.channelnewsasia.com/business/seeking-oecd-membership-indonesia-reviews-economic-policies-4370811',
#    'summary': '',
#    'summary_detail': {'type': 'text/html',
#     'language': 'en',
#     'base': 'https://www.channelnewsasia.com/',
#     'value': ''},
#    'published': 'Wed, 29 May 2024 13:37:14 +0800',
#    'published_parsed': time.struct_time(tm_year=2024, tm_mon=5, tm_mday=29, tm_hour=5, tm_min=37, tm_sec=14, tm_wday=2, tm_yday=150, tm_isdst=0),
#    'id': 'https://www.channelnewsasia.com/business/seeking-oecd-membership-indonesia-reviews-economic-policies-4370811',
#    'guidislink': False,
#    'tags': [{'term': 'Business', 'scheme': None, 'label': None}],
#    'media_thumbnail': [{'url': 'https://onecms-res.cloudinary.com/image/upload/s--mxD3Dw__--/c_fill,h_900,w_1600/fl_relative,g_south_east,l_mediacorp:cna:watermark:2024-04:reuters_1,w_0.1/f_auto,q_auto/v1/one-cms/core/2024-05-29t053714z_1_lynxmpek4s069_rtroptp_3_indonesia-economy-gdp.jpg?itok=P0dcjnYi',
#      'width': '1600',
#      'height': '900'}],
#    'href': ''},
#   {'title': "Japan must restore fiscal discipline to protect yen's value, LDP panel says",
#    'title_detail': {'type': 'text/plain',
#     'language': 'en',
#     'base': 'https://www.channelnewsasia.com/',
#     'value': "Japan must restore fiscal discipline to protect yen's value, LDP panel says"},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.channelnewsasia.com/business/japan-must-restore-fiscal-discipline-protect-yens-value-ldp-panel-says-4370681'}],
#    'link': 'https://www.channelnewsasia.com/business/japan-must-restore-fiscal-discipline-protect-yens-value-ldp-panel-says-4370681',
#    'summary': '',
#    'summary_detail': {'type': 'text/html',
#     'language': 'en',
#     'base': 'https://www.channelnewsasia.com/',
#     'value': ''},
#    'published': 'Wed, 29 May 2024 12:42:10 +0800',
#    'published_parsed': time.struct_time(tm_year=2024, tm_mon=5, tm_mday=29, tm_hour=4, tm_min=42, tm_sec=10, tm_wday=2, tm_yday=150, tm_isdst=0),
#    'id': 'https://www.channelnewsasia.com/business/japan-must-restore-fiscal-discipline-protect-yens-value-ldp-panel-says-4370681',
#    'guidislink': False,
#    'tags': [{'term': 'Business', 'scheme': None, 'label': None}],
#    'media_thumbnail': [{'url': 'https://onecms-res.cloudinary.com/image/upload/s--4RNJWrHi--/c_fill,h_900,w_1600/fl_relative,g_south_east,l_mediacorp:cna:watermark:2024-04:reuters_1,w_0.1/f_auto,q_auto/v1/one-cms/core/2024-05-29t044210z_1_lynxmpek4s050_rtroptp_3_japan-economy-boj.jpg?itok=VPDGjVKf',
#      'width': '1600',
#      'height': '900'}],
#    'href': ''},
#   {'title': "Vietnam inflation rises in May, nears government's limit",
#    'title_detail': {'type': 'text/plain',
#     'language': 'en',
#     'base': 'https://www.channelnewsasia.com/',
#     'value': "Vietnam inflation rises in May, nears government's limit"},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.channelnewsasia.com/business/vietnam-inflation-rises-may-nears-governments-limit-4370516'}],
#    'link': 'https://www.channelnewsasia.com/business/vietnam-inflation-rises-may-nears-governments-limit-4370516',
#    'summary': '',
#    'summary_detail': {'type': 'text/html',
#     'language': 'en',
#     'base': 'https://www.channelnewsasia.com/',
#     'value': ''},
#    'published': 'Wed, 29 May 2024 11:32:00 +0800',
#    'published_parsed': time.struct_time(tm_year=2024, tm_mon=5, tm_mday=29, tm_hour=3, tm_min=32, tm_sec=0, tm_wday=2, tm_yday=150, tm_isdst=0),
#    'id': 'https://www.channelnewsasia.com/business/vietnam-inflation-rises-may-nears-governments-limit-4370516',
#    'guidislink': False,
#    'tags': [{'term': 'Business ,Asia', 'scheme': None, 'label': None}],
#    'media_thumbnail': [{'url': 'https://onecms-res.cloudinary.com/image/upload/s--zIyYzZI---/c_fill,h_900,w_1600/fl_relative,g_south_east,l_mediacorp:cna:watermark:2024-04:reuters_1,w_0.1/f_auto,q_auto/v1/one-cms/core/2024-05-29t040926z_2_lynxmpek4s03f_rtroptp_3_global-retail.jpg?itok=38h9yWhM',
#      'width': '1600',
#      'height': '900'}],
#    'href': ''},
#   {'title': 'Ex-OpenAI board member provides her first detailed account of CEO ouster',
#    'title_detail': {'type': 'text/plain',
#     'language': 'en',
#     'base': 'https://www.channelnewsasia.com/',
#     'value': 'Ex-OpenAI board member provides her first detailed account of CEO ouster'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.channelnewsasia.com/business/ex-openai-board-member-provides-her-first-detailed-account-ceo-ouster-4370441'}],
#    'link': 'https://www.channelnewsasia.com/business/ex-openai-board-member-provides-her-first-detailed-account-ceo-ouster-4370441',
#    'summary': '',
#    'summary_detail': {'type': 'text/html',
#     'language': 'en',
#     'base': 'https://www.channelnewsasia.com/',
#     'value': ''},
#    'published': 'Wed, 29 May 2024 11:04:42 +0800',
#    'published_parsed': time.struct_time(tm_year=2024, tm_mon=5, tm_mday=29, tm_hour=3, tm_min=4, tm_sec=42, tm_wday=2, tm_yday=150, tm_isdst=0),
#    'id': 'https://www.channelnewsasia.com/business/ex-openai-board-member-provides-her-first-detailed-account-ceo-ouster-4370441',
#    'guidislink': False,
#    'tags': [{'term': 'Business', 'scheme': None, 'label': None}],
#    'media_thumbnail': [{'url': 'https://onecms-res.cloudinary.com/image/upload/s--trEZkF4K--/c_fill,h_900,w_1600/fl_relative,g_south_east,l_mediacorp:cna:watermark:2024-04:reuters_1,w_0.1/f_auto,q_auto/v1/one-cms/core/2024-05-29t030442z_2_lynxmpek4s030_rtroptp_3_davos-meeting.jpg?itok=n20Ry_qL',
#      'width': '1600',
#      'height': '900'}],
#    'href': ''},
#   {'title': "BOJ policymaker hints at rate hike if yen's impact on inflation is big",
#    'title_detail': {'type': 'text/plain',
#     'language': 'en',
#     'base': 'https://www.channelnewsasia.com/',
#     'value': "BOJ policymaker hints at rate hike if yen's impact on inflation is big"},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.channelnewsasia.com/business/boj-policymaker-hints-rate-hike-if-yens-impact-inflation-big-4370326'}],
#    'link': 'https://www.channelnewsasia.com/business/boj-policymaker-hints-rate-hike-if-yens-impact-inflation-big-4370326',
#    'summary': '',
#    'summary_detail': {'type': 'text/html',
#     'language': 'en',
#     'base': 'https://www.channelnewsasia.com/',
#     'value': ''},
#    'published': 'Wed, 29 May 2024 10:26:13 +0800',
#    'published_parsed': time.struct_time(tm_year=2024, tm_mon=5, tm_mday=29, tm_hour=2, tm_min=26, tm_sec=13, tm_wday=2, tm_yday=150, tm_isdst=0),
#    'id': 'https://www.channelnewsasia.com/business/boj-policymaker-hints-rate-hike-if-yens-impact-inflation-big-4370326',
#    'guidislink': False,
#    'tags': [{'term': 'Business', 'scheme': None, 'label': None}],
#    'media_thumbnail': [{'url': 'https://onecms-res.cloudinary.com/image/upload/s--dD0BFipw--/c_fill,h_900,w_1600/fl_relative,g_south_east,l_mediacorp:cna:watermark:2024-04:reuters_1,w_0.1/f_auto,q_auto/v1/one-cms/core/2024-05-29t032248z_2_lynxmpek4s026_rtroptp_3_japan-economy-boj.jpg?itok=43NqmJZc',
#      'width': '1600',
#      'height': '900'}],
#    'href': ''},
#   {'title': 'China’s yuan seeks to challenge the US dollar but traders don’t want to use it',
#    'title_detail': {'type': 'text/plain',
#     'language': 'en',
#     'base': 'https://www.channelnewsasia.com/',
#     'value': 'China’s yuan seeks to challenge the US dollar but traders don’t want to use it'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.channelnewsasia.com/east-asia/china-yuan-challenge-us-dollar-traders-will-not-use-survey-4370181'}],
#    'link': 'https://www.channelnewsasia.com/east-asia/china-yuan-challenge-us-dollar-traders-will-not-use-survey-4370181',
#    'summary': '',
#    'summary_detail': {'type': 'text/html',
#     'language': 'en',
#     'base': 'https://www.channelnewsasia.com/',
#     'value': ''},
#    'published': 'Wed, 29 May 2024 10:23:00 +0800',
#    'published_parsed': time.struct_time(tm_year=2024, tm_mon=5, tm_mday=29, tm_hour=2, tm_min=23, tm_sec=0, tm_wday=2, tm_yday=150, tm_isdst=0),
#    'id': 'https://www.channelnewsasia.com/east-asia/china-yuan-challenge-us-dollar-traders-will-not-use-survey-4370181',
#    'guidislink': False,
#    'tags': [{'term': 'East Asia ,Asia ,Business',
#      'scheme': None,
#      'label': None}],
#    'media_thumbnail': [{'url': 'https://onecms-res.cloudinary.com/image/upload/s--XcGGrty6--/c_crop,h_450,w_800,x_0,y_0/c_fill,h_900,w_1600/fl_relative,g_south_east,l_mediacorp:cna:watermark:2024-04:reuters_1,w_0.1/f_auto,q_auto/v1/one-cms/core/2024-05-09t235255z_1_lynxmpek480xr_rtroptp_3_china-economy-beigebook.jpg?itok=a2sLANYf',
#      'width': '1600',
#      'height': '900'}],
#    'href': ''},
#   {'title': 'Union at Samsung Electronics in South Korea says to take strike action',
#    'title_detail': {'type': 'text/plain',
#     'language': 'en',
#     'base': 'https://www.channelnewsasia.com/',
#     'value': 'Union at Samsung Electronics in South Korea says to take strike action'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.channelnewsasia.com/east-asia/union-samsung-electronics-south-korea-says-take-strike-action-4370316'}],
#    'link': 'https://www.channelnewsasia.com/east-asia/union-samsung-electronics-south-korea-says-take-strike-action-4370316',
#    'summary': '',
#    'summary_detail': {'type': 'text/html',
#     'language': 'en',
#     'base': 'https://www.channelnewsasia.com/',
#     'value': ''},
#    'published': 'Wed, 29 May 2024 10:22:00 +0800',
#    'published_parsed': time.struct_time(tm_year=2024, tm_mon=5, tm_mday=29, tm_hour=2, tm_min=22, tm_sec=0, tm_wday=2, tm_yday=150, tm_isdst=0),
#    'id': 'https://www.channelnewsasia.com/east-asia/union-samsung-electronics-south-korea-says-take-strike-action-4370316',
#    'guidislink': False,
#    'tags': [{'term': 'East Asia ,Business', 'scheme': None, 'label': None}],
#    'media_thumbnail': [{'url': 'https://onecms-res.cloudinary.com/image/upload/s--JK9Vm6wv--/c_fill,h_900,w_1600/fl_relative,g_south_east,l_mediacorp:cna:watermark:2024-04:reuters_1,w_0.1/f_auto,q_auto/v1/one-cms/core/2024-05-29t025131z_2_lynxmpek4s02i_rtroptp_3_samsung-elec-union.jpg?itok=CpqcFtmS',
#      'width': '1600',
#      'height': '900'}],
#    'href': ''},
#   {'title': "IMF upgrades China's 2024, 2025 GDP growth forecasts after 'strong' Q1",
#    'title_detail': {'type': 'text/plain',
#     'language': 'en',
#     'base': 'https://www.channelnewsasia.com/',
#     'value': "IMF upgrades China's 2024, 2025 GDP growth forecasts after 'strong' Q1"},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.channelnewsasia.com/east-asia/imf-upgrades-chinas-2024-2025-gdp-growth-forecasts-after-strong-q1-4370256'}],
#    'link': 'https://www.channelnewsasia.com/east-asia/imf-upgrades-chinas-2024-2025-gdp-growth-forecasts-after-strong-q1-4370256',
#    'summary': '',
#    'summary_detail': {'type': 'text/html',
#     'language': 'en',
#     'base': 'https://www.channelnewsasia.com/',
#     'value': ''},
#    'published': 'Wed, 29 May 2024 10:19:08 +0800',
#    'published_parsed': time.struct_time(tm_year=2024, tm_mon=5, tm_mday=29, tm_hour=2, tm_min=19, tm_sec=8, tm_wday=2, tm_yday=150, tm_isdst=0),
#    'id': 'https://www.channelnewsasia.com/east-asia/imf-upgrades-chinas-2024-2025-gdp-growth-forecasts-after-strong-q1-4370256',
#    'guidislink': False,
#    'tags': [{'term': 'East Asia ,Business', 'scheme': None, 'label': None}],
#    'media_thumbnail': [{'url': 'https://onecms-res.cloudinary.com/image/upload/s--V1l9JCEU--/c_fill,h_900,w_1600/fl_relative,g_south_east,l_mediacorp:cna:watermark:2024-04:reuters_1,w_0.1/f_auto,q_auto/v1/one-cms/core/2024-05-29t020750z_2_lynxmpek4s01s_rtroptp_3_china-economy-gdp.jpg?itok=fvro1MAW',
#      'width': '1600',
#      'height': '900'}],
#    'href': ''},
#   {'title': "Musk's Starlink back up after brief outage",
#    'title_detail': {'type': 'text/plain',
#     'language': 'en',
#     'base': 'https://www.channelnewsasia.com/',
#     'value': "Musk's Starlink back up after brief outage"},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.channelnewsasia.com/business/musks-starlink-back-after-brief-outage-4370276'}],
#    'link': 'https://www.channelnewsasia.com/business/musks-starlink-back-after-brief-outage-4370276',
#    'summary': '',
#    'summary_detail': {'type': 'text/html',
#     'language': 'en',
#     'base': 'https://www.channelnewsasia.com/',
#     'value': ''},
#    'published': 'Wed, 29 May 2024 10:13:00 +0800',
#    'published_parsed': time.struct_time(tm_year=2024, tm_mon=5, tm_mday=29, tm_hour=2, tm_min=13, tm_sec=0, tm_wday=2, tm_yday=150, tm_isdst=0),
#    'id': 'https://www.channelnewsasia.com/business/musks-starlink-back-after-brief-outage-4370276',
#    'guidislink': False,
#    'tags': [{'term': 'Business', 'scheme': None, 'label': None}],
#    'media_thumbnail': [{}],
#    'href': ''},
#   {'title': 'Dollar steady ahead of inflation data, yen hits 4-week low',
#    'title_detail': {'type': 'text/plain',
#     'language': 'en',
#     'base': 'https://www.channelnewsasia.com/',
#     'value': 'Dollar steady ahead of inflation data, yen hits 4-week low'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.channelnewsasia.com/business/dollar-steady-ahead-inflation-data-yen-hits-4-week-low-4370281'}],
#    'link': 'https://www.channelnewsasia.com/business/dollar-steady-ahead-inflation-data-yen-hits-4-week-low-4370281',
#    'summary': '',
#    'summary_detail': {'type': 'text/html',
#     'language': 'en',
#     'base': 'https://www.channelnewsasia.com/',
#     'value': ''},
#    'published': 'Wed, 29 May 2024 10:10:44 +0800',
#    'published_parsed': time.struct_time(tm_year=2024, tm_mon=5, tm_mday=29, tm_hour=2, tm_min=10, tm_sec=44, tm_wday=2, tm_yday=150, tm_isdst=0),
#    'id': 'https://www.channelnewsasia.com/business/dollar-steady-ahead-inflation-data-yen-hits-4-week-low-4370281',
#    'guidislink': False,
#    'tags': [{'term': 'Business', 'scheme': None, 'label': None}],
#    'media_thumbnail': [{'url': 'https://onecms-res.cloudinary.com/image/upload/s--G-yLHmuJ--/c_fill,h_900,w_1600/fl_relative,g_south_east,l_mediacorp:cna:watermark:2024-04:reuters_1,w_0.1/f_auto,q_auto/v1/one-cms/core/2024-05-29t021451z_2_lynxmpek4s01v_rtroptp_3_svb-financial-group-stock.jpg?itok=XHMW7319',
#      'width': '1600',
#      'height': '900'}],
#    'href': ''},
#   {'title': 'Oil advances as major producers expected to keep output cuts in place',
#    'title_detail': {'type': 'text/plain',
#     'language': 'en',
#     'base': 'https://www.channelnewsasia.com/',
#     'value': 'Oil advances as major producers expected to keep output cuts in place'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.channelnewsasia.com/business/oil-advances-major-producers-expected-keep-output-cuts-place-4370116'}],
#    'link': 'https://www.channelnewsasia.com/business/oil-advances-major-producers-expected-keep-output-cuts-place-4370116',
#    'summary': '',
#    'summary_detail': {'type': 'text/html',
#     'language': 'en',
#     'base': 'https://www.channelnewsasia.com/',
#     'value': ''},
#    'published': 'Wed, 29 May 2024 08:49:55 +0800',
#    'published_parsed': time.struct_time(tm_year=2024, tm_mon=5, tm_mday=29, tm_hour=0, tm_min=49, tm_sec=55, tm_wday=2, tm_yday=150, tm_isdst=0),
#    'id': 'https://www.channelnewsasia.com/business/oil-advances-major-producers-expected-keep-output-cuts-place-4370116',
#    'guidislink': False,
#    'tags': [{'term': 'Business', 'scheme': None, 'label': None}],
#    'media_thumbnail': [{'url': 'https://onecms-res.cloudinary.com/image/upload/s---VGHadXw--/c_fill,h_900,w_1600/fl_relative,g_south_east,l_mediacorp:cna:watermark:2024-04:reuters_1,w_0.1/f_auto,q_auto/v1/one-cms/core/2024-05-29t004955z_1_lynxmpek4s00p_rtroptp_3_global-oil.jpg?itok=6fE_NjJS',
#      'width': '1600',
#      'height': '900'}],
#    'href': ''},
#   {'title': "Cathie Wood's Ark buys stake in Musk's xAI, Bloomberg News reports",
#    'title_detail': {'type': 'text/plain',
#     'language': 'en',
#     'base': 'https://www.channelnewsasia.com/',
#     'value': "Cathie Wood's Ark buys stake in Musk's xAI, Bloomberg News reports"},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.channelnewsasia.com/business/cathie-woods-ark-buys-stake-musks-xai-bloomberg-news-reports-4370066'}],
#    'link': 'https://www.channelnewsasia.com/business/cathie-woods-ark-buys-stake-musks-xai-bloomberg-news-reports-4370066',
#    'summary': '',
#    'summary_detail': {'type': 'text/html',
#     'language': 'en',
#     'base': 'https://www.channelnewsasia.com/',
#     'value': ''},
#    'published': 'Wed, 29 May 2024 07:59:04 +0800',
#    'published_parsed': time.struct_time(tm_year=2024, tm_mon=5, tm_mday=28, tm_hour=23, tm_min=59, tm_sec=4, tm_wday=1, tm_yday=149, tm_isdst=0),
#    'id': 'https://www.channelnewsasia.com/business/cathie-woods-ark-buys-stake-musks-xai-bloomberg-news-reports-4370066',
#    'guidislink': False,
#    'tags': [{'term': 'Business', 'scheme': None, 'label': None}],
#    'media_thumbnail': [{'url': 'https://onecms-res.cloudinary.com/image/upload/s--JGnoei-b--/c_fill,h_900,w_1600/fl_relative,g_south_east,l_mediacorp:cna:watermark:2024-04:reuters_1,w_0.1/f_auto,q_auto/v1/one-cms/core/2024-05-29t000420z_2_lynxmpek4r0t3_rtroptp_3_usa-funds-ark.jpg?itok=F4pnDwTR',
#      'width': '1600',
#      'height': '900'}],
#    'href': ''},
#   {'title': 'Morning Bid: Japanese consumers, Aussie CPI in focus',
#    'title_detail': {'type': 'text/plain',
#     'language': 'en',
#     'base': 'https://www.channelnewsasia.com/',
#     'value': 'Morning Bid: Japanese consumers, Aussie CPI in focus'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.channelnewsasia.com/business/morning-bid-japanese-consumers-aussie-cpi-focus-4369881'}],
#    'link': 'https://www.channelnewsasia.com/business/morning-bid-japanese-consumers-aussie-cpi-focus-4369881',
#    'summary': '',
#    'summary_detail': {'type': 'text/html',
#     'language': 'en',
#     'base': 'https://www.channelnewsasia.com/',
#     'value': ''},
#    'published': 'Wed, 29 May 2024 05:48:30 +0800',
#    'published_parsed': time.struct_time(tm_year=2024, tm_mon=5, tm_mday=28, tm_hour=21, tm_min=48, tm_sec=30, tm_wday=1, tm_yday=149, tm_isdst=0),
#    'id': 'https://www.channelnewsasia.com/business/morning-bid-japanese-consumers-aussie-cpi-focus-4369881',
#    'guidislink': False,
#    'tags': [{'term': 'Business', 'scheme': None, 'label': None}],
#    'media_thumbnail': [{'url': 'https://onecms-res.cloudinary.com/image/upload/s--UuxTlOAo--/c_fill,h_900,w_1600/fl_relative,g_south_east,l_mediacorp:cna:watermark:2024-04:reuters_1,w_0.1/f_auto,q_auto/v1/one-cms/core/2024-05-28t214830z_1_lynxmpek4r0rr_rtroptp_3_global-markets.jpg?itok=CzdvuKun',
#      'width': '1600',
#      'height': '900'}],
#    'href': ''},
#   {'title': 'US presses TikTok, Meta and X to crack down on antisemitic posts, Bloomberg News reports',
#    'title_detail': {'type': 'text/plain',
#     'language': 'en',
#     'base': 'https://www.channelnewsasia.com/',
#     'value': 'US presses TikTok, Meta and X to crack down on antisemitic posts, Bloomberg News reports'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.channelnewsasia.com/business/us-presses-tiktok-meta-and-x-crack-down-antisemitic-posts-bloomberg-news-reports-4369791'}],
#    'link': 'https://www.channelnewsasia.com/business/us-presses-tiktok-meta-and-x-crack-down-antisemitic-posts-bloomberg-news-reports-4369791',
#    'summary': '',
#    'summary_detail': {'type': 'text/html',
#     'language': 'en',
#     'base': 'https://www.channelnewsasia.com/',
#     'value': ''},
#    'published': 'Wed, 29 May 2024 04:49:04 +0800',
#    'published_parsed': time.struct_time(tm_year=2024, tm_mon=5, tm_mday=28, tm_hour=20, tm_min=49, tm_sec=4, tm_wday=1, tm_yday=149, tm_isdst=0),
#    'id': 'https://www.channelnewsasia.com/business/us-presses-tiktok-meta-and-x-crack-down-antisemitic-posts-bloomberg-news-reports-4369791',
#    'guidislink': False,
#    'tags': [{'term': 'Business', 'scheme': None, 'label': None}],
#    'media_thumbnail': [{}],
#    'href': ''},
#   {'title': 'Trading app Robinhood unveils maiden stock buyback plan of $1 billion',
#    'title_detail': {'type': 'text/plain',
#     'language': 'en',
#     'base': 'https://www.channelnewsasia.com/',
#     'value': 'Trading app Robinhood unveils maiden stock buyback plan of $1 billion'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.channelnewsasia.com/business/trading-app-robinhood-unveils-maiden-stock-buyback-plan-1-billion-4369751'}],
#    'link': 'https://www.channelnewsasia.com/business/trading-app-robinhood-unveils-maiden-stock-buyback-plan-1-billion-4369751',
#    'summary': '',
#    'summary_detail': {'type': 'text/html',
#     'language': 'en',
#     'base': 'https://www.channelnewsasia.com/',
#     'value': ''},
#    'published': 'Wed, 29 May 2024 04:16:08 +0800',
#    'published_parsed': time.struct_time(tm_year=2024, tm_mon=5, tm_mday=28, tm_hour=20, tm_min=16, tm_sec=8, tm_wday=1, tm_yday=149, tm_isdst=0),
#    'id': 'https://www.channelnewsasia.com/business/trading-app-robinhood-unveils-maiden-stock-buyback-plan-1-billion-4369751',
#    'guidislink': False,
#    'tags': [{'term': 'Business', 'scheme': None, 'label': None}],
#    'media_thumbnail': [{'url': 'https://onecms-res.cloudinary.com/image/upload/s--nN27XLAg--/c_fill,h_900,w_1600/fl_relative,g_south_east,l_mediacorp:cna:watermark:2024-04:reuters_1,w_0.1/f_auto,q_auto/v1/one-cms/core/2024-05-28t201608z_1_lynxmpek4r0q0_rtroptp_3_robinhood-stocks.jpg?itok=7lOorQtU',
#      'width': '1600',
#      'height': '900'}],
#    'href': ''},
#   {'title': 'Verizon adds Peacock to streaming hub, offers discounted YouTube premium plan to customers',
#    'title_detail': {'type': 'text/plain',
#     'language': 'en',
#     'base': 'https://www.channelnewsasia.com/',
#     'value': 'Verizon adds Peacock to streaming hub, offers discounted YouTube premium plan to customers'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.channelnewsasia.com/business/verizon-adds-peacock-streaming-hub-offers-discounted-youtube-premium-plan-customers-4369701'}],
#    'link': 'https://www.channelnewsasia.com/business/verizon-adds-peacock-streaming-hub-offers-discounted-youtube-premium-plan-customers-4369701',
#    'summary': '',
#    'summary_detail': {'type': 'text/html',
#     'language': 'en',
#     'base': 'https://www.channelnewsasia.com/',
#     'value': ''},
#    'published': 'Wed, 29 May 2024 03:48:14 +0800',
#    'published_parsed': time.struct_time(tm_year=2024, tm_mon=5, tm_mday=28, tm_hour=19, tm_min=48, tm_sec=14, tm_wday=1, tm_yday=149, tm_isdst=0),
#    'id': 'https://www.channelnewsasia.com/business/verizon-adds-peacock-streaming-hub-offers-discounted-youtube-premium-plan-customers-4369701',
#    'guidislink': False,
#    'tags': [{'term': 'Business', 'scheme': None, 'label': None}],
#    'media_thumbnail': [{'url': 'https://onecms-res.cloudinary.com/image/upload/s--QtW_XJco--/c_fill,h_900,w_1600/fl_relative,g_south_east,l_mediacorp:cna:watermark:2024-04:reuters_1,w_0.1/f_auto,q_auto/v1/one-cms/core/2024-05-28t200023z_1_lynxmpek4r0pt_rtroptp_3_verizon-youtube.jpg?itok=MZNfJPH1',
#      'width': '1600',
#      'height': '900'}],
#    'href': ''},
#   {'title': 'EU in touch with Telegram as it nears criterion for EU tech rules',
#    'title_detail': {'type': 'text/plain',
#     'language': 'en',
#     'base': 'https://www.channelnewsasia.com/',
#     'value': 'EU in touch with Telegram as it nears criterion for EU tech rules'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.channelnewsasia.com/business/eu-touch-telegram-it-nears-criterion-eu-tech-rules-4369426'}],
#    'link': 'https://www.channelnewsasia.com/business/eu-touch-telegram-it-nears-criterion-eu-tech-rules-4369426',
#    'summary': '',
#    'summary_detail': {'type': 'text/html',
#     'language': 'en',
#     'base': 'https://www.channelnewsasia.com/',
#     'value': ''},
#    'published': 'Wed, 29 May 2024 01:22:02 +0800',
#    'published_parsed': time.struct_time(tm_year=2024, tm_mon=5, tm_mday=28, tm_hour=17, tm_min=22, tm_sec=2, tm_wday=1, tm_yday=149, tm_isdst=0),
#    'id': 'https://www.channelnewsasia.com/business/eu-touch-telegram-it-nears-criterion-eu-tech-rules-4369426',
#    'guidislink': False,
#    'tags': [{'term': 'Business', 'scheme': None, 'label': None}],
#    'media_thumbnail': [{'url': 'https://onecms-res.cloudinary.com/image/upload/s--PUgmgt7B--/c_fill,h_900,w_1600/fl_relative,g_south_east,l_mediacorp:cna:watermark:2024-04:reuters_1,w_0.1/f_auto,q_auto/v1/one-cms/core/2024-05-28t211051z_2_lynxmpek4r0o4_rtroptp_3_eu-telegram-tech.jpg?itok=es-oDNSA',
#      'width': '1600',
#      'height': '900'}],
#    'href': ''},
#   {'title': "Italy's Vega-C rocket a step closer to returning to flight after successful engine test",
#    'title_detail': {'type': 'text/plain',
#     'language': 'en',
#     'base': 'https://www.channelnewsasia.com/',
#     'value': "Italy's Vega-C rocket a step closer to returning to flight after successful engine test"},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.channelnewsasia.com/business/italys-vega-c-rocket-step-closer-returning-flight-after-successful-engine-test-4369366'}],
#    'link': 'https://www.channelnewsasia.com/business/italys-vega-c-rocket-step-closer-returning-flight-after-successful-engine-test-4369366',
#    'summary': '',
#    'summary_detail': {'type': 'text/html',
#     'language': 'en',
#     'base': 'https://www.channelnewsasia.com/',
#     'value': ''},
#    'published': 'Wed, 29 May 2024 00:47:45 +0800',
#    'published_parsed': time.struct_time(tm_year=2024, tm_mon=5, tm_mday=28, tm_hour=16, tm_min=47, tm_sec=45, tm_wday=1, tm_yday=149, tm_isdst=0),
#    'id': 'https://www.channelnewsasia.com/business/italys-vega-c-rocket-step-closer-returning-flight-after-successful-engine-test-4369366',
#    'guidislink': False,
#    'tags': [{'term': 'Business', 'scheme': None, 'label': None}],
#    'media_thumbnail': [{}],
#    'href': ''},
#   {'title': 'Volkswagen to develop entry-level electric vehicles for 20,000 euros',
#    'title_detail': {'type': 'text/plain',
#     'language': 'en',
#     'base': 'https://www.channelnewsasia.com/',
#     'value': 'Volkswagen to develop entry-level electric vehicles for 20,000 euros'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.channelnewsasia.com/business/volkswagen-develop-low-cost-electric-car-tackle-chinese-rivals-4369286'}],
#    'link': 'https://www.channelnewsasia.com/business/volkswagen-develop-low-cost-electric-car-tackle-chinese-rivals-4369286',
#    'summary': '',
#    'summary_detail': {'type': 'text/html',
#     'language': 'en',
#     'base': 'https://www.channelnewsasia.com/',
#     'value': ''},
#    'published': 'Wed, 29 May 2024 00:04:05 +0800',
#    'published_parsed': time.struct_time(tm_year=2024, tm_mon=5, tm_mday=28, tm_hour=16, tm_min=4, tm_sec=5, tm_wday=1, tm_yday=149, tm_isdst=0),
#    'id': 'https://www.channelnewsasia.com/business/volkswagen-develop-low-cost-electric-car-tackle-chinese-rivals-4369286',
#    'guidislink': False,
#    'tags': [{'term': 'Business', 'scheme': None, 'label': None}],
#    'media_thumbnail': [{}],
#    'href': ''}],
#  'feed': {'language': 'en',
#   'title': 'Latest News',
#   'title_detail': {'type': 'text/plain',
#    'language': 'en',
#    'base': 'https://www.channelnewsasia.com/',
#    'value': 'Latest News'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'https://www.channelnewsasia.com/'}],
#   'link': 'https://www.channelnewsasia.com/',
#   'subtitle': 'mediacorp feed news',
#   'subtitle_detail': {'type': 'text/html',
#    'language': 'en',
#    'base': 'https://www.channelnewsasia.com/',
#    'value': 'mediacorp feed news'},
#   'updated': 'Wed, 29 May 2024 15:06:16 +0800',
#   'updated_parsed': time.struct_time(tm_year=2024, tm_mon=5, tm_mday=29, tm_hour=7, tm_min=6, tm_sec=16, tm_wday=2, tm_yday=150, tm_isdst=0),
#   'generator_detail': {'name': 'Mediacorp'},
#   'generator': 'Mediacorp',
#   'ttl': '20',
#   'image': {'href': 'https://www.channelnewsasia.com/image/8395694/1x1/114/114/eb06a179c414e4534ff4417b64f3710c/kC/apple-touch-icon.png',
#    'title': 'Latest News',
#    'title_detail': {'type': 'text/plain',
#     'language': 'en',
#     'base': 'https://www.channelnewsasia.com/',
#     'value': 'Latest News'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.channelnewsasia.com/'}],
#    'link': 'https://www.channelnewsasia.com/',
#    'width': 114,
#    'height': 114,
#    'subtitle': 'mediacorp feed news',
#    'subtitle_detail': {'type': 'text/html',
#     'language': 'en',
#     'base': 'https://www.channelnewsasia.com/',
#     'value': 'mediacorp feed news'}}},
#  'headers': {'last-modified': 'Wed, 29 May 2024 07:06:14 GMT',
#   'etag': '"1716966374"',
#   'server': 'nginx',
#   'content-type': 'text/xml; charset=utf-8',
#   'x-drupal-dynamic-cache': 'MISS',
#   'x-ua-compatible': 'IE=edge',
#   'content-language': 'en',
#   'x-content-type-options': 'nosniff',
#   'x-frame-options': 'SAMEORIGIN',
#   'permissions-policy': 'interest-cohort=()',
#   'x-request-id': 'v-eff017d4-1d89-11ef-8c0c-3b40b4d6ecb2',
#   'x-ah-environment': 'prod',
#   'x-cache-hits': '1',
#   'x-age': '26',
#   'accept-ranges': 'bytes',
#   'x-cdn': 'Imperva',
#   'content-encoding': 'gzip',
#   'x-iinfo': '13-62620546-62620774 SNYN RT(1716966340722 62030) q(0 0 0 1) r(0 0) U24',
#   'content-length': '3432',
#   'cache-control': 'public, max-age=199',
#   'expires': 'Wed, 29 May 2024 07:11:43 GMT',
#   'date': 'Wed, 29 May 2024 07:08:24 GMT',
#   'connection': 'close',
#   'vary': 'Accept-Encoding',
#   'strict-transport-security': 'max-age=31536000'},
#  'etag': '"1716966374"',
#  'updated': 'Wed, 29 May 2024 07:06:14 GMT',
#  'updated_parsed': time.struct_time(tm_year=2024, tm_mon=5, tm_mday=29, tm_hour=7, tm_min=6, tm_sec=14, tm_wday=2, tm_yday=150, tm_isdst=0),
#  'href': 'https://www.channelnewsasia.com/api/v1/rss-outbound-feed?_format=xml&category=6936',
#  'status': 200,
#  'encoding': 'utf-8',
#  'version': 'rss20',
#  'namespaces': {'dc': 'http://purl.org/dc/elements/1.1/',
#   'content': 'http://purl.org/rss/1.0/modules/content/',
#   'foaf': 'http://xmlns.com/foaf/0.1/',
#   'og': 'http://ogp.me/ns#',
#   'rdfs': 'http://www.w3.org/2000/01/rdf-schema#',
#   'schema': 'http://schema.org/',
#   'sioc': 'http://rdfs.org/sioc/ns#',
#   'sioct': 'http://rdfs.org/sioc/types#',
#   'skos': 'http://www.w3.org/2004/02/skos/core#',
#   'xsd': 'http://www.w3.org/2001/XMLSchema#',
#   '': 'http://www.w3.org/2005/Atom',
#   'media': 'http://search.yahoo.com/mrss/'}}
